# %% [markdown]
# # Gunc simulated genomes type 3b: analyze stage1 hitlist results

# %%
setwd("..")

# %%
library(dplyr)
library(readr)
library(tidyr)
library(ggplot2)

# %% [markdown]
# ## Read in stage1_hitlist results

# %%
stage1_rs202_reps <- read_csv("sandbox/gunc_synthetic_genomes3b/type3b.genomes/outputs/genomes_to_charcoal3_vs_gtdb_rs202_reps/stage1_hitlist.csv", show_col_types = F)
stage1_rs207_reps <- read_csv("sandbox/gunc_synthetic_genomes3b/type3b.genomes/outputs/genomes_to_charcoal3_vs_gtdb_rs207_reps/stage1_hitlist.csv", show_col_types = F)

# %% [markdown]
# ## Do something

# %%
# parse the stage1 hitlist
# contamination_level: what is the "control" level of contamination? -- e.g., what is the lowest common ancestor for the combined genomes?
# level_first_bad_bp: what is the taxonomic level of the first bad base pair that was detected?
stage1_rs207_reps <- stage1_rs207_reps %>%
  mutate(contamination_level = gsub("type3b_", "", genome),
         contamination_level = gsub("_.*", "", contamination_level)) %>%
  mutate(level_first_bad_bp = ifelse(phylum_bad_bp > 0, "phylum", 
                                    ifelse(phylum_bad_bp == 0 & class_bad_bp > 0, "class",
                                          ifelse(phylum_bad_bp == 0 & class_bad_bp == 0 & order_bad_bp > 0, "order", 
                                                ifelse(phylum_bad_bp == 0 & class_bad_bp == 0 & order_bad_bp == 0 & family_bad_bp > 0, "family", "genus")))))

# %%
# parse stage1 hitlist 
# level_majority_bad_bp: at what taxonomic level is the majority of contamination detected? 
stage1_rs207_reps_majority_bad_bp <- stage1_rs207_reps %>%
  select(genome, contamination_level, ends_with("bad_bp")) %>% 
  select(-total_bad_bp, -level_first_bad_bp) %>%
  pivot_longer(cols = ends_with("bad_bp"), names_to = "level_bad_bp", values_to = "base_pairs") %>% # pivot to longer
  mutate(base_pairs = base_pairs - 50000) %>% # subtract 50k bp; rm tiny contam detection, as contam should be ~2/3 of seq
  filter(base_pairs > 0) %>%                  # limit to bad bp greater than 0
  group_by(genome) %>%                        # group to genome
  slice_head(n = 1) %>%                       # select highest contam after 50bp rm within each genome
  mutate(level_bad_bp = gsub("_bad_bp", "", level_bad_bp)) %>% # edit name of level with majority contam
  select(genome, level_majority_bad_bp = level_bad_bp)
  

stage1_rs207_reps <- left_join(stage1_rs207_reps, stage1_rs207_reps_majority_bad_bp, by = "genome")

# %%
stage1_rs207_reps
# Out:
#    genome                                             filter_at
# 1  type3b_class_3_0.33_0000_1121877.SAMN02745886_.fa  order
# 2  type3b_phylum_3_0.33_0000_1280.SAMEA862559_.fa     order
# 3  type3b_phylum_3_0.33_0000_1280.SAMN04018804_.fa    order
# 4  type3b_phylum_3_0.33_0000_1313.SAMEA1025997_.fa    order
# 5  type3b_class_3_0.33_0000_1231054.SAMN01730125_.fa  order
# 6  type3b_order_3_0.33_0000_1050199.SAMN02261318_.fa  order
# 7  type3b_order_3_0.33_0000_119857.SAMN03773898_.fa   order
# 53       0            0      4073482       4073482      1.000   0.820
# 54       0            0      1454197       1454197      0.999   0.687
# 55       0            0      3939369       3939369      1.000   0.824
# 56       0            0      2819323       2819323      1.000   0.744
# 57       0            0      3647683       3647683      0.999   0.790
# 58       0            0      3617675       3617675      1.000   0.712
# 59       0            0      1431244       1431244      1.000   0.840
# 60       0            0      1726329       1726329      1.000   0.837
#    lineage
# 1  d__Bacteria;p__Actinobacteriota;c__Acidimicrobiia;o__Acidimicrobiales
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 3  d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 4  d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 5  d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 6  d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Streptomycetales
# 7  d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Francisellales
# 8  d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales
# 9  d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Streptomycetales
# 10 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales
# 11 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 12 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 13 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales_A
# 14 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Selenomonadales
# 15 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 16 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Peptostreptococcales
# 17 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales
# 18 d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 19 d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales
# 20 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales_A
# 21 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Propionisporales
# 22 d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 23 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Actinomycetales
# 24 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 25 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 26 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 27 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 28 d__Bacteria;p__Campylobacterota;c__Campylobacteria;o__Campylobacterales
# 29 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales
# 30 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 31 d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Propionisporales
# 32 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales
# 33 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Tissierellales
# 34 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 35 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 36 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 37 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 38 d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 39 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 40 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 41 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Peptostreptococcales
# 42 d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 43 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 44 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales
# 45 d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 46 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales
# 47 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 48 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales
# 49 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
# 50 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales
# 51 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 52 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales
# 53 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 54 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales
# 55 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 56 d__Bacteria;p__Actinobacteriota;c__Actinomycetia;o__Mycobacteriales
# 57 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 58 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
# 59 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Francisellales
# 60 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales
#    comment contamination_level level_first_bad_bp level_majority_bad_bp
# 1  NA      class               class              class
# 2  NA      phylum              phylum             phylum
# 3  NA      phylum              phylum             phylum
# 4  NA      phylum              phylum             phylum
# 5  NA      class               class              class
# 6  NA      order               order              order
# 7  NA      order               phylum             order
# 8  NA      class               phylum             phylum
# 9  NA      order               order              order
# 10 NA      order               phylum             order
# 11 NA      phylum              phylum             phylum
# 12 NA      phylum              phylum             phylum
# 13 NA      class               phylum             phylum
# 14 NA      class               phylum             phylum
# 15 NA      phylum              phylum             phylum
# 16 NA      family              phylum             order
# 17 NA      class               phylum             class
# 18 NA      family              phylum             order
# 19 NA      genus               order              order
# 20 NA      order               order              order
# 21 NA      class               phylum             phylum
# 22 NA      family              order              order
# 23 NA      order               class              order
# 24 NA      order               order              order
# 25 NA      order               phylum             order
# 26 NA      order               order              order
# 27 NA      phylum              phylum             phylum
# 28 NA      phylum              phylum             phylum
# 29 NA      class               phylum             phylum
# 30 NA      phylum              phylum             phylum
# 31 NA      class               phylum             phylum
# 32 NA      phylum              phylum             phylum
# 33 NA      class               phylum             phylum
# 34 NA      family              phylum             family
# 35 NA      specI               phylum             family
# 36 NA      family              phylum             family
# 37 NA      specI               phylum             family
# 38 NA      specI               phylum             family
# 39 NA      specI               phylum             family
# 40 NA      family              phylum             family
# 41 NA      genus               phylum             family
# 42 NA      specI               phylum             family
# 43 NA      family              order              family
# 44 NA      genus               phylum             family
# 45 NA      specI               phylum             family
# 46 NA      specI               order              family
# 47 NA      family              order              family
# 48 NA      specI               order              family
# 49 NA      family              phylum             family
# 50 NA      genus               phylum             family
# 51 NA      family              family             family
# 52 NA      genus               family             family
# 53 NA      genus               family             family
# 54 NA      genus               family             family
# 55 NA      genus               family             family
# 56 NA      genus               family             family
# 57 NA      genus               family             family
# 58 NA      order               family             family
# 59 NA      specI               family             family
# 60 NA      specI               family             family

# %%
table(stage1_rs207_reps$contamination_level == stage1_rs207_reps$level_first_bad_bp)
# Out:
# FALSE  TRUE
#    42    18

# %%
table(stage1_rs207_reps$contamination_level == stage1_rs207_reps$level_majority_bad_bp)
# Out:
# FALSE  TRUE
#    31    29

# %% [markdown]
# Charcoal doesn't really work for contamination detection below the family/order level.
# This might be because there are too many shared k-mers? ASK TESSA

# %%
stage1_rs207_reps_filt <- stage1_rs207_reps %>%
  filter(! contamination_level %in% c("genus", "specI"))

# %%
table(stage1_rs207_reps_filt$contamination_level == stage1_rs207_reps_filt$level_majority_bad_bp)
# Out:
# FALSE  TRUE
#    11    29

# %% [markdown]
# ## dig in to the 11 that don't match
#
# **Hypotheses as to what is happening**
#
# 1. GTDB taxonomy is different than the NCBI taxonomy, so the majority contamination level is accurate but doesn't match the declared level.
#    - CHECK: the taxonomy of the combined genomes in GTDB. Makes the most sense for contams that are only one level off from where they are supposed to be
# 2. The progenomes2.1 genomes used to build these simulated genomes are contaminated.
#    - not really sure what to check here

# %%
stage1_rs207_reps_filt[stage1_rs207_reps_filt$contamination_level != stage1_rs207_reps_filt$level_majority_bad_bp, ]
# Out:
#    genome                                            filter_at
# 1  type3b_class_3_0.33_0000_1287313.SAMN02359689_.fa order
# 2  type3b_class_3_0.33_0000_1160201.SAMN00811184_.fa order
# 3  type3b_class_3_0.33_0000_1123249.SAMN02440643_.fa order
# 4  type3b_family_3_0.33_0000_1502.SAMN05323905_.fa   order
# 5  type3b_family_3_0.33_0000_1428.SAMN04278951_.fa   order
# 6  type3b_class_3_0.33_0000_1149862.SAMN01057330_.fa order
# 7  type3b_family_3_0.33_0000_1433.SAMN05934573_.fa   order
# 8  type3b_class_3_0.33_0000_1298595.SAMD00000528_.fa order
# 9  type3b_class_3_0.33_0000_1122947.SAMN01057329_.fa order
# 10 type3b_class_3_0.33_0000_1505.SAMEA1572114_.fa    order
# 11 type3b_order_3_0.33_0000_115545.SAMN06140942_.fa  none
#    override_filter_at total_bad_bp superkingdom_bad_bp phylum_bad_bp
# 1  NA                 2405605      0                   1347104
# 2  NA                 2150493      0                   1150803
# 3  NA                 2115170      0                   2110752
# 4  NA                 1745042      0                      9598
# 5  NA                 1608222      0                      3232
# 6  NA                 1416265      0                   1416265
# 7  NA                 1374471      0                         0
# 8  NA                  934477      0                    934477
# 9  NA                  892586      0                    892586
# 10 NA                  888160      0                    528434
# 11 NA                       0      0                         0
#    class_bad_bp order_bad_bp family_bad_bp genus_bad_bp f_ident f_major
# 1  2405605      2405605      3517455       3517455      0.403   0.702
# 2  2142891      2150493      3381158       3381158      0.406   0.759
# 3  2110752      2115170      3335498       3335498      0.377   0.892
# 4     9598      1745042      2948860       2948860      0.436   0.673
# 5     3232      1608222      2487568       2487568      0.364   0.931
# 6  1416265      1416265      2084567       2084567      0.367   0.845
# 7        0      1374471      2135877       2135877      0.377   0.863
# 8   934477       934477      1526760       1526760      0.414   0.822
# 9   892586       892586      1465097       1465097      0.425   0.778
# 10  528434       888160      1527073       1527073      0.432   0.777
# 11       0            0      3617675       3617675      1.000   0.712
#    lineage
# 1  d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales
# 2  d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales_A
# 3  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Selenomonadales
# 4  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Peptostreptococcales
# 5  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 6  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Propionisporales
# 7  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphylococcales
# 8  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Veillonellales
# 9  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o__Propionisporales
# 10 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Tissierellales
# 11 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales
#    comment contamination_level level_first_bad_bp level_majority_bad_bp
# 1  NA      class               phylum             phylum
# 2  NA      class               phylum             phylum
# 3  NA      class               phylum             phylum
# 4  NA      family              phylum             order
# 5  NA      family              phylum             order
# 6  NA      class               phylum             phylum
# 7  NA      family              order              order
# 8  NA      class               phylum             phylum
# 9  NA      class               phylum             phylum
# 10 NA      class               phylum             phylum
# 11 NA      order               family             family

# %% [markdown]
# tldr used other notebooks; when contigs are re-assigned taxonomy via GTDB, everything meshes how its supposed to.
